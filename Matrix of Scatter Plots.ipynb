# %%
import pandas as pd
import numpy as np
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11971cb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119d68f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119dbb690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119e2e910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10501ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119f273d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119fb54d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a14d350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a1b93d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a23d250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a2a1190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a418fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a47ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a508dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a58bc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a5fb6d0>]], dtype=object)

# %% [markdown]
# Or use the matrix tool in Seaborn...

# %%
import seaborn as sns
sns.set()

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
